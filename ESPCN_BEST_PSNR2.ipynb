# %%
#THIS CODE DOWNLOAD FROM https://github.com/jeetyadav98/ESPCN-PyTorch
#FOR LOCAL MACHINE RUNNING, YOu CAN USE BELOW COMMANDS
#python3 main.py --print-config
#python main.py --train
#python3 main.py --test-image
# !git clone https://github.com/niazwazir/WAZIR_ESPCN1
# Out:
# Cloning into 'WAZIR_ESPCN1'...
# remote: Enumerating objects: 224, done.
# remote: Counting objects: 100% (224/224), done.
# remote: Compressing objects: 100% (126/126), done.
# remote: Total 224 (delta 105), reused 163 (delta 86), pack-reused 0
# Receiving objects: 100% (224/224), 35.36 MiB | 19.72 MiB/s, done.
# Resolving deltas: 100% (105/105), done.

# %%
cd WAZIR_ESPCN1/
# Out:
# /content/WAZIR_ESPCN1

# %%
# !ls
# Out:
# config.yaml  LICENSE  prepare.py  requirements.txt  thumbnails
# data	     main.py  README.md   source

# %%
cd data/datasets/
# Out:
# /content/WAZIR_ESPCN1/data/datasets

# %%
# !ls
# Out:
# 91-image_x3.zip  Set5_x3.h5

# %%
# !unzip 91-image_x3.zip
# Out:
# Archive:  91-image_x3.zip
#   inflating: 91-image_x3.h5

# %%
# !ls
# Out:
# 91-image_x3.h5	91-image_x3.zip  Set5_x3.h5

# %%
cd ..
# Out:
# /content/WAZIR_ESPCN1/data

# %%
cd ..
# Out:
# /content/WAZIR_ESPCN1

# %%
# !ls
# Out:
# config.yaml  LICENSE  prepare.py  requirements.txt  thumbnails
# data	     main.py  README.md   source

# %%
# !pip3 install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 49.9 MB 37 kB/s
# ...
#      |████████████████████████████████| 10.3 MB 56.8 MB/s
# ...
#      |████████████████████████████████| 76 kB 6.6 MB/s
# ...
#      |████████████████████████████████| 636 kB 60.3 MB/s
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ...

# %%
# !python3 main.py --print-config
# Out:
# Configuration parameters-
#
# training :
#    training file : data/datasets/91-image_x3.h5
#    eval file : data/datasets/Set5_x3.h5
#    output dir : data/weights
#    scale : 3
#    lr : 1e-3
#    batch size : 16
#    number of epochs : 200
#    number of workers : 8
#    seed : 123
#
# test image :
#    weights file : data/weights/x3/best.pth
#    scale : 3
#    image dir : data/Set5
#    image file : butterfly.png
#
# test video :
#    weights file : data/weights/x3/best.pth
#    scale : 3
#    video dir : data/xiph-videos
#    video file : ducks_take_off_1080p.avi
#
# visualize filters :
#    weights file : data/weights/x3/best.pth
#    scale : 3

# %%
# !python3 main.py --train
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch: 0/199: : 2701it [00:16, 164.71it/s, loss=0.010885]
# eval psnr: 26.47
# epoch: 1/199:   0%|                                    | 0/2688 [00:00<?, ?it/s][W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# ...

# %%
cd ..
# Out:
# /content/WAZIR_ESPCN1/data

# %%
cd ..
# Out:
# /content/WAZIR_ESPCN1

# %%
# !ls
# Out:
# config.yaml  LICENSE  prepare.py  requirements.txt  thumbnails
# data	     main.py  README.md   source

# %%
# !python3 main.py --test-image
# Out:
# butterfly.png
# PSNR ESPCN  : 28.19
# PSNR Bicubic: 24.52
